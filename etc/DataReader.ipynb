# %%
from pandas_datareader import data as pdr
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# https://fred.stlouisfed.org/series/GOLDAMGBD228NLBM

# %%
df = pdr.DataReader('GOLDAMGBD228NLBM','fred','2000-01-01')

# %%
df.head()
# Out:
#             GOLDAMGBD228NLBM
# DATE
# 2000-01-03               NaN
# 2000-01-04            282.05
# 2000-01-05            282.10
# 2000-01-06            280.35
# 2000-01-07            282.00

# %%
df2 = pdr.DataReader('SLVPRUSD','fred','2000-01-01')

# %%
df3 = pdr.DataReader(['GOLDAMGBD228NLBM','SLVPRUSD'],'fred','2000-01-01')

# %%
df2.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df3.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
def myreader(*args, src='fred', sdate='2000-01-01', edate=None,col=None, cview=True):
    df = pdr.DataReader(args, src, sdate)
    print(df.shape)
    print(df.head())
#     if col:
#         df.sdt_columns()
    if cview:
        df.plot()

# %%
myreader('GOLDAMGBD228NLBM','SLVPRUSD')
# Out:
# (5580, 2)
#             GOLDAMGBD228NLBM  SLVPRUSD
# DATE
# 2000-01-03               NaN       NaN
# 2000-01-04            282.05       NaN
# 2000-01-05            282.10       NaN
# 2000-01-06            280.35       NaN
# 2000-01-07            282.00       NaN

# %%
myreader('PCOPPUSDM')
# Out:
# (256, 1)
#               PCOPPUSDM
# DATE
# 2000-01-01  1843.850000
# 2000-02-01  1807.025000
# 2000-03-01  1739.800000
# 2000-04-01  1681.907500
# 2000-05-01  1785.097826

# %%
myreader('PMAIZMTUSDM')
# Out:
# (256, 1)
#             PMAIZMTUSDM
# DATE
# 2000-01-01    92.953275
# 2000-02-01    95.081619
# 2000-03-01    95.169351
# 2000-04-01    95.539373
# 2000-05-01    95.530551

# %%
myreader('DCOILWTICO')
# Out:
# (5576, 1)
#             DCOILWTICO
# DATE
# 2000-01-03         NaN
# 2000-01-04       25.56
# 2000-01-05       24.65
# 2000-01-06       24.79
# 2000-01-07       24.79

# %%
# 유가 : DCOILWTICO(WTI), POILDUBUSDM(dubai), DCOILBRENTEU(brent)

# %%
myreader('POILWTIUSDM','POILDUBUSDM','POILBREUSDM')
# Out:
# (256, 3)
#             POILWTIUSDM  POILDUBUSDM  POILBREUSDM
# DATE
# 2000-01-01        27.24        23.18        25.22
# 2000-02-01        29.21        24.62        27.63
# 2000-03-01        29.92        25.08        27.47
# 2000-04-01        25.78        22.03        22.54
# 2000-05-01        28.78        25.51        27.40

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-ea942bf769f0> in <module>
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable
