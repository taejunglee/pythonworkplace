# %%
import numpy as np
from scipy import stats
import pandas as pd

# %%
gender = pd.DataFrame(np.random.choice(2,10000, p=[0.51, 0.49]))
age = pd.DataFrame(np.random.choice(5,10000, p=[0.1753, 0.1941, 0.1871, 0.2079, 0.2356]))
job = pd.DataFrame(np.random.choice(11,10000, p=[0.0230, 0.06, 0.2306, 0.1525, 0.2531, 0.0920, 0.07, 0.0340, 0.0546, 0.0076, 0.0226]))
family_size = pd.DataFrame(np.random.choice(4, 10000, p=[0.452, 0.208, 0.308, 0.032]))
child_num = pd.DataFrame(np.random.choice(4, 10000, p=[0.422, 0.217, 0.333, 0.028]))
income = pd.DataFrame(np.random.choice(6, 10000, p=[0.234, 0.284, 0.166, 0.118, 0.066, 0.132]))
knowledge = pd.DataFrame(np.random.choice(4, 10000, p=[0.537, 0.146, 0.183, 0.134]))
exp = pd.DataFrame(np.random.choice(4, 10000, p=[0.189, 0.15, 0.457, 0.204]))
risk = pd.DataFrame(np.random.choice(4,10000, p=[0.425, 0.432, 0.099, 0.044]))
term = pd.DataFrame(np.random.choice(4,10000, p=[0.136, 0.258, 0.360, 0.246]))

# %%
s1 = pd.DataFrame(0.821 * np.random.randn(10000) +2.645) 
s2 = pd.DataFrame(0.617 * np.random.randn(10000)+ 1.542)
s3 = pd.DataFrame(0.800 * np.random.randn(10000)+ 1.400)
s4 = pd.DataFrame(0.962 * np.random.randn(10000)+ 2.275)
s5 = pd.DataFrame(0.588 * np.random.randn(10000)+ 1.408)

# %%
data = pd.concat([gender,age,job,family_size,child_num,income,knowledge,exp,risk,term,s1,s2,s3,s4,s5],axis=1)
data.columns = ["gender","age","job","family_size","child_num","income","knowledge","exp","risk","term","s1","s2","s3","s4","s5"]

# %%
data
# Out:
#        gender  age  job  family_size  child_num  income  knowledge  exp  risk  \
# 0           0    1    4            0          0       0          1    3     2
# 1           1    0    4            3          0       5          2    2     1
# 2           0    2    6            1          1       0          0    1     1
# 3           1    4    4            0          0       1          2    2     0
# 4           1    3    2            0          1       1          0    2     0
# ...       ...  ...  ...          ...        ...     ...        ...  ...   ...
# 49995       1    1    8            0          0       1          2    2     0
# 49996       1    1    4            1          1       1          0    2     0
# 49997       0    0   10            2          2       1          0    1     1
# 49998       0    4    3            2          3       0          1    2     2
# 49999       0    1    2            1          0       0          0    2     1
#
# ...

# %%
data.to_csv('data8.csv')
