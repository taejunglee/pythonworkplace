# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

# %%
df = pd.read_csv("CLI.csv", index_col=0)

# %%
df
# Out:
#          INDICATOR   SUBJECT    MEASURE FREQUENCY     TIME      Value  \
# LOCATION
# GBR            CLI  AMPLITUD  LTRENDIDX         M  1957-12   97.46449
# GBR            CLI  AMPLITUD  LTRENDIDX         M  1958-01   97.51181
# GBR            CLI  AMPLITUD  LTRENDIDX         M  1958-02   97.63669
# GBR            CLI  AMPLITUD  LTRENDIDX         M  1958-03   97.80425
# GBR            CLI  AMPLITUD  LTRENDIDX         M  1958-04   97.98584
# ...            ...       ...        ...       ...      ...        ...
# COL            CLI  AMPLITUD  LTRENDIDX         M  2022-01  101.55210
# COL            CLI  AMPLITUD  LTRENDIDX         M  2022-02  101.36830
# COL            CLI  AMPLITUD  LTRENDIDX         M  2022-03  101.16170
# COL            CLI  AMPLITUD  LTRENDIDX         M  2022-04  100.95410
# COL            CLI  AMPLITUD  LTRENDIDX         M  2022-05  100.76840
#
#           Flag Codes
# LOCATION
# GBR              NaN
# GBR              NaN
# GBR              NaN
# ...

# %%
df_kor = df.loc['KOR']

# %%
df_kor[['TIME',"Value"]]
# Out:
#              TIME      Value
# LOCATION
# KOR       1990-01  100.18310
# KOR       1990-02  100.05360
# KOR       1990-03   99.98537
# KOR       1990-04   99.92226
# KOR       1990-05   99.83148
# ...           ...        ...
# KOR       2022-01   99.83620
# KOR       2022-02   99.59853
# KOR       2022-03   99.36751
# KOR       2022-04   99.14036
# KOR       2022-05   98.92125
#
# [389 rows x 2 columns]

# %%
df_kor['TIME']
# Out:
# LOCATION
# KOR    1990-01
# KOR    1990-02
# KOR    1990-03
# KOR    1990-04
# KOR    1990-05
#         ...
# KOR    2022-01
# KOR    2022-02
# KOR    2022-03
# KOR    2022-04
# KOR    2022-05
# Name: TIME, Length: 389, dtype: object

# %%
plt.figure(figsize=(18,8))
plt.plot(df_kor['TIME'],df_kor['Value'])
plt.xlabel('Time')
plt.ylabel('Value')
plt.xticks(rotation=70)  
plt.legend



plt.grid(True)

plt.show()
