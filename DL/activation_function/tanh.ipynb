# %% [markdown]
# S자 모양이지만 -1 ~ 1 사이의 값을 출력함

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def tanh(x):
    return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

x = np.arange(-10, 10, 0.1)
y = tanh(x)

plt.plot(x,y)
plt.title('tanh function')
plt.show()
