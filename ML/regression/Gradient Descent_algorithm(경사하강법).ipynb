# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - 업데이트할 w = learning Rate *((Y예측 - Y실제)*X)평균
# - 업데이트할 b = learning Rate *((Y예측 - Y실제)*1)평균

# %% [markdown]
# # 샘플에 활용할 셋 구성

# %%
def make_linear(w=0.5, b=0.8, size=50, noise=1.0):
    x = np.random.rand(size)
    y = w * x + b
    noise = np.random.uniform(-abs(noise), abs(noise), size=y.shape)
    yy = y + noise
    plt.figure(figsize=(10, 7))
    plt.plot(x, y, color='r', label=f'y = {w}*x + {b}')
    plt.scatter(x, yy, label='data')
    plt.legend(fontsize=20)
    plt.show()
    print(f'w: {w}, b: {b}')
    return x, yy

# %%
x, y = make_linear(w=0.3, b=0.5, size=100, noise=0.01)
# 임의로 2개의 outlier를 추가
y[5] = 0.75
y[10] = 0.75

plt.figure(figsize=(10, 7))
plt.scatter(x, y)
plt.show()
# Out:
# w: 0.3, b: 0.5

# %% [markdown]
# # 초기값, 예측(Y_hat) 정의

# %%
w = np.random.uniform(low=-1.0, high=1.0)
b = np.random.uniform(low=-1.0, high=1.0)

# %%
y_hat = w * x + b

# %%
error = (y_hat - y) ** 2

# %%
# 최대 반복 횟수
num_epoch = 300

# 학습율 (learning_rate)
learning_rate = 0.01

# %%
errors = []
# random 한 값으로 w, b를 초기화 합니다.
w = np.random.uniform(low=-1.0, high=1.0)
b = np.random.uniform(low=-1.0, high=1.0)

for epoch in range(num_epoch):
    y_hat = x * w + b

    error = ((y_hat - y)**2).mean()
    if error < 0.0006:
        break
    
    w = w - learning_rate * ((y_hat - y) * x).mean()
    b = b - learning_rate * (y_hat - y).mean()
    
    errors.append(error)
    
    if epoch % 5 == 0: # 5의 배수마다 확인
        print("{0:2} w = {1:.5f}, b = {2:.5f} error = {3:.5f}".format(epoch, w, b, error))

print("----" * 15)
print("{0:2} w = {1:.1f}, b = {2:.1f} error = {3:.5f}".format(epoch, w, b, error))
# Out:
#  0 w = 0.41153, b = 0.68175 error = 0.05806
#  5 w = 0.40543, b = 0.67037 error = 0.05126
# 10 w = 0.39970, b = 0.65970 error = 0.04527
# 15 w = 0.39431, b = 0.64967 error = 0.03999
# 20 w = 0.38924, b = 0.64027 error = 0.03534
# 25 w = 0.38448, b = 0.63144 error = 0.03123
# 30 w = 0.38000, b = 0.62315 error = 0.02762
# 35 w = 0.37579, b = 0.61538 error = 0.02443
# 40 w = 0.37183, b = 0.60808 error = 0.02162
# 45 w = 0.36810, b = 0.60123 error = 0.01914
# 50 w = 0.36460, b = 0.59481 error = 0.01696
# 55 w = 0.36131, b = 0.58878 error = 0.01503
# 60 w = 0.35821, b = 0.58312 error = 0.01333
# 65 w = 0.35529, b = 0.57781 error = 0.01184
# 70 w = 0.35254, b = 0.57283 error = 0.01052
# 75 w = 0.34996, b = 0.56816 error = 0.00936
# 80 w = 0.34753, b = 0.56377 error = 0.00833
# 85 w = 0.34524, b = 0.55966 error = 0.00743
# 90 w = 0.34308, b = 0.55580 error = 0.00663
# 95 w = 0.34105, b = 0.55218 error = 0.00593
# 100 w = 0.33914, b = 0.54879 error = 0.00531
# 105 w = 0.33734, b = 0.54560 error = 0.00476
# 110 w = 0.33564, b = 0.54262 error = 0.00428
# 115 w = 0.33404, b = 0.53982 error = 0.00386
# 120 w = 0.33254, b = 0.53719 error = 0.00348
# 125 w = 0.33111, b = 0.53473 error = 0.00316
# 130 w = 0.32977, b = 0.53242 error = 0.00286
# 135 w = 0.32851, b = 0.53025 error = 0.00261
# 140 w = 0.32732, b = 0.52822 error = 0.00238
# 145 w = 0.32619, b = 0.52632 error = 0.00218
# 150 w = 0.32513, b = 0.52454 error = 0.00201
# 155 w = 0.32412, b = 0.52287 error = 0.00185
# 160 w = 0.32317, b = 0.52130 error = 0.00172
# 165 w = 0.32228, b = 0.51983 error = 0.00159
# 170 w = 0.32143, b = 0.51846 error = 0.00149
# 175 w = 0.32063, b = 0.51717 error = 0.00139
# 180 w = 0.31987, b = 0.51597 error = 0.00131
# 185 w = 0.31915, b = 0.51484 error = 0.00124
# 190 w = 0.31847, b = 0.51378 error = 0.00117
# 195 w = 0.31783, b = 0.51279 error = 0.00112
# 200 w = 0.31722, b = 0.51186 error = 0.00107
# 205 w = 0.31664, b = 0.51100 error = 0.00102
# 210 w = 0.31609, b = 0.51019 error = 0.00098
# 215 w = 0.31557, b = 0.50943 error = 0.00095
# 220 w = 0.31508, b = 0.50872 error = 0.00092
# 225 w = 0.31461, b = 0.50806 error = 0.00089
# 230 w = 0.31416, b = 0.50744 error = 0.00087
# 235 w = 0.31374, b = 0.50686 error = 0.00085
# 240 w = 0.31333, b = 0.50632 error = 0.00083
# 245 w = 0.31295, b = 0.50582 error = 0.00081
# 250 w = 0.31258, b = 0.50535 error = 0.00080
# 255 w = 0.31223, b = 0.50491 error = 0.00079
# 260 w = 0.31190, b = 0.50450 error = 0.00077
# 265 w = 0.31158, b = 0.50412 error = 0.00076
# 270 w = 0.31127, b = 0.50376 error = 0.00076
# 275 w = 0.31098, b = 0.50343 error = 0.00075
# 280 w = 0.31070, b = 0.50312 error = 0.00074
# 285 w = 0.31044, b = 0.50284 error = 0.00073
# 290 w = 0.31018, b = 0.50257 error = 0.00073
# 295 w = 0.30993, b = 0.50232 error = 0.00072
# ------------------------------------------------------------
# 299 w = 0.3, b = 0.5 error = 0.00072

# %%
plt.figure(figsize=(10, 7))
plt.plot(errors)
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# # 다항식

# %%
x1 = np.random.rand(100)
x2 = np.random.rand(100)
x3 = np.random.rand(100)

# %%
w1 = np.random.uniform(low=-1.0, high=1.0)
w2 = np.random.uniform(low=-1.0, high=1.0)
w3 = np.random.uniform(low=-1.0, high=1.0)

b = np.random.uniform(low=-1.0, high=1.0)

# %%
y = 0.3 * x1 + 0.5 * x2 + 0.7 * x3 + b

# %% [markdown]
# # Gradient Descent 구현 (다항식)

# %%
errors = []
w1_grad = []
w2_grad = []
w3_grad = []

num_epoch=5000
learning_rate=0.5

w1 = np.random.uniform(low=-1.0, high=1.0)
w2 = np.random.uniform(low=-1.0, high=1.0)
w3 = np.random.uniform(low=-1.0, high=1.0)

b1 = np.random.uniform(low=-1.0, high=1.0)
b2 = np.random.uniform(low=-1.0, high=1.0)
b3 = np.random.uniform(low=-1.0, high=1.0)

for epoch in range(num_epoch):
    # 예측값
    y_hat = w1 * x1 + w2 * x2 + w3 * x3 + b

    error = ((y_hat - y)**2).mean()
    if error < 0.00001:
        break
    
    # 미분값 적용 (Gradient)
    w1 = w1 - learning_rate * ((y_hat - y) * x1).mean()
    w2 = w2 - learning_rate * ((y_hat - y) * x2).mean()
    w3 = w3 - learning_rate * ((y_hat - y) * x3).mean()
    
    w1_grad.append(w1)
    w2_grad.append(w2)
    w3_grad.append(w3)
    
    b = b - learning_rate * (y_hat - y).mean()
    
    errors.append(error)
    
    if epoch % 5 == 0:
        print("{0:2} w1 = {1:.5f}, w2 = {2:.5f}, w3 = {3:.5f}, b = {4:.5f} error = {5:.5f}".format(epoch, w1, w2, w3, b, error))

print("----" * 15)
print("{0:2} w1 = {1:.1f}, w2 = {2:.1f}, w3 = {3:.1f}, b = {4:.1f} error = {5:.5f}".format(epoch, w1, w2, w3, b, error))
# Out:
#  0 w1 = -0.22065, w2 = -0.31564, w3 = 0.25227, b = 1.61752 error = 2.18785
#  5 w1 = -0.12858, w2 = -0.15358, w3 = 0.33690, b = 1.64864 error = 0.05985
# 10 w1 = -0.09556, w2 = -0.06808, w3 = 0.36638, b = 1.57288 error = 0.04736
# 15 w1 = -0.06344, w2 = 0.00472, w3 = 0.39434, b = 1.50499 error = 0.03762
# 20 w1 = -0.03269, w2 = 0.06697, w3 = 0.42065, b = 1.44416 error = 0.02997
# 25 w1 = -0.00360, w2 = 0.12040, w3 = 0.44524, b = 1.38963 error = 0.02393
# 30 w1 = 0.02367, w2 = 0.16644, w3 = 0.46809, b = 1.34076 error = 0.01915
# 35 w1 = 0.04903, w2 = 0.20626, w3 = 0.48923, b = 1.29694 error = 0.01534
# 40 w1 = 0.07249, w2 = 0.24081, w3 = 0.50870, b = 1.25766 error = 0.01230
# 45 w1 = 0.09407, w2 = 0.27088, w3 = 0.52660, b = 1.22244 error = 0.00987
# 50 w1 = 0.11386, w2 = 0.29714, w3 = 0.54298, b = 1.19085 error = 0.00793
# 55 w1 = 0.13193, w2 = 0.32012, w3 = 0.55796, b = 1.16252 error = 0.00637
# 60 w1 = 0.14839, w2 = 0.34029, w3 = 0.57161, b = 1.13712 error = 0.00512
# 65 w1 = 0.16336, w2 = 0.35803, w3 = 0.58404, b = 1.11433 error = 0.00412
# 70 w1 = 0.17693, w2 = 0.37367, w3 = 0.59534, b = 1.09390 error = 0.00331
# 75 w1 = 0.18922, w2 = 0.38748, w3 = 0.60559, b = 1.07557 error = 0.00267
# 80 w1 = 0.20033, w2 = 0.39969, w3 = 0.61488, b = 1.05912 error = 0.00214
# 85 w1 = 0.21037, w2 = 0.41052, w3 = 0.62329, b = 1.04437 error = 0.00173
# 90 w1 = 0.21943, w2 = 0.42012, w3 = 0.63090, b = 1.03114 error = 0.00139
# 95 w1 = 0.22759, w2 = 0.42865, w3 = 0.63778, b = 1.01927 error = 0.00112
# 100 w1 = 0.23495, w2 = 0.43624, w3 = 0.64399, b = 1.00862 error = 0.00090
# 105 w1 = 0.24157, w2 = 0.44299, w3 = 0.64960, b = 0.99907 error = 0.00072
# 110 w1 = 0.24753, w2 = 0.44901, w3 = 0.65466, b = 0.99050 error = 0.00058
# 115 w1 = 0.25289, w2 = 0.45437, w3 = 0.65922, b = 0.98281 error = 0.00047
# 120 w1 = 0.25770, w2 = 0.45916, w3 = 0.66333, b = 0.97591 error = 0.00038
# 125 w1 = 0.26203, w2 = 0.46344, w3 = 0.66704, b = 0.96973 error = 0.00030
# 130 w1 = 0.26592, w2 = 0.46726, w3 = 0.67037, b = 0.96417 error = 0.00024
# 135 w1 = 0.26941, w2 = 0.47067, w3 = 0.67337, b = 0.95919 error = 0.00020
# 140 w1 = 0.27255, w2 = 0.47373, w3 = 0.67607, b = 0.95472 error = 0.00016
# 145 w1 = 0.27537, w2 = 0.47646, w3 = 0.67850, b = 0.95071 error = 0.00013
# 150 w1 = 0.27790, w2 = 0.47890, w3 = 0.68069, b = 0.94712 error = 0.00010
# 155 w1 = 0.28017, w2 = 0.48109, w3 = 0.68265, b = 0.94389 error = 0.00008
# 160 w1 = 0.28221, w2 = 0.48305, w3 = 0.68442, b = 0.94099 error = 0.00007
# 165 w1 = 0.28403, w2 = 0.48480, w3 = 0.68601, b = 0.93840 error = 0.00005
# 170 w1 = 0.28568, w2 = 0.48638, w3 = 0.68743, b = 0.93607 error = 0.00004
# 175 w1 = 0.28715, w2 = 0.48778, w3 = 0.68872, b = 0.93397 error = 0.00003
# 180 w1 = 0.28847, w2 = 0.48905, w3 = 0.68987, b = 0.93210 error = 0.00003
# 185 w1 = 0.28965, w2 = 0.49018, w3 = 0.69090, b = 0.93041 error = 0.00002
# 190 w1 = 0.29072, w2 = 0.49119, w3 = 0.69183, b = 0.92890 error = 0.00002
# 195 w1 = 0.29167, w2 = 0.49210, w3 = 0.69267, b = 0.92755 error = 0.00001
# 200 w1 = 0.29253, w2 = 0.49291, w3 = 0.69342, b = 0.92633 error = 0.00001
# ------------------------------------------------------------
# 204 w1 = 0.3, w2 = 0.5, w3 = 0.7, b = 0.9 error = 0.00001

# %%
plt.figure(figsize=(10, 7))

plt.plot(errors)

# %%
plt.figure(figsize=(10, 7))

plt.hlines(y=0.3, xmin=0, xmax=len(w1_grad), color='r')
plt.plot(w1_grad, color='g')
plt.ylim(0, 1)
plt.title('W1', fontsize=16)
plt.legend(['W1 Change', 'W1'])
plt.show()

# %%
plt.figure(figsize=(10, 7))

plt.hlines(y=0.5, xmin=0, xmax=len(w2_grad), color='r')
plt.plot(w2_grad, color='g')
plt.ylim(0, 1)
plt.title('W2', fontsize=16)
plt.legend(['W2 Change', 'W2'])
plt.show()

# %%
plt.figure(figsize=(10, 7))

plt.hlines(y=0.7, xmin=0, xmax=len(w3_grad), color='r')
plt.plot(w3_grad, color='g')
plt.ylim(0, 1)
plt.title('W3', fontsize=16)
plt.legend(['W3 Change', 'W3'])
plt.show()
